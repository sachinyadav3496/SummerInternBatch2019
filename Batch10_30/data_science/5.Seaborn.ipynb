# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
x = [ 1,2,3,4,5,6]
y = [ 6,7,5,3,2,6]

# %%
plt.plot(x,y)#line
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(x,y)
plt.setp(ax.xaxis.get_majorticklabels(),rotation=90)
ax.set_xticks([1,2,3,4,5])
ax.set_yticks(range(0,10))
ax.set_xticklabels(["India","Pakisthan","SouthAfrica","Australia"])

plt.show()

# %%
plt.xticks(rotation=45)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %%
import seaborn as sns

# %%
# scatter plot
sns.get_dataset_names()
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
import pandas as pd

# %%
df  = pd.read_csv("seaborn-data/tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = plt.figure(figsize=(5,3))
ax = plt.subplot(111)
sns.distplot(df['total_bill'],kde=False,bins=30,color='red',ax=ax)
ax.set_title("This is Distribution Plot",fontsize=20)
plt.grid()
plt.show()

# %%
sns.pairplot(df,hue='sex')

# %%
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.scatterplot("tip","total_bill",hue="smoker",data=df,palette='rainbow',
               size="size")
plt.show()

# %%
sns.jointplot("total_bill","tip",data=df,color="red",kind='kde')
plt.show()

# %%
sns.jointplot("total_bill","tip",data=df,color="red",kind='hex')
plt.show()

# %%
df = pd.read_csv("seaborn-data/diamonds.csv")

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.distplot(df["price"],kde=False)
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['price'].mean()
# Out:
# 3932.799721913237

# %%
import numpy as np 
df['price'].median()
# Out:
# 2401.0

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(5,4))
ax = fig.add_subplot(111)
sns.boxenplot(x="price",data=df,orient='v',ax=ax)
plt.show()

# %%
sns.scatterplot("carat","price",data=df,hue="cut",size="color")
plt.show()

# %%
print(dir(sns))
# Out:
# ['FacetGrid', 'JointGrid', 'PairGrid', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_orig_rc_params', 'algorithms', 'axes_style', 'axisgrid', 'barplot', 'blend_palette', 'boxenplot', 'boxplot', 'categorical', 'catplot', 'choose_colorbrewer_palette', 'choose_cubehelix_palette', 'choose_dark_palette', 'choose_diverging_palette', 'choose_light_palette', 'clustermap', 'cm', 'color_palette', 'colors', 'countplot', 'crayon_palette', 'crayons', 'cubehelix_palette', 'dark_palette', 'desaturate', 'despine', 'distplot', 'distributions', 'diverging_palette', 'dogplot', 'external', 'factorplot', 'get_dataset_names', 'heatmap', 'hls_palette', 'husl_palette', 'jointplot', 'kdeplot', 'light_palette', 'lineplot', 'lmplot', 'load_dataset', 'lvplot', 'matrix', 'miscplot', 'mpl', 'mpl_palette', 'pairplot', 'palettes', 'palplot', 'plotting_context', 'pointplot', 'rcmod', 'regplot', 'regression', 'relational', 'relpl
# ...

# %%
df = pd.read_csv("seaborn-data/tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
df = pd.read_csv("seaborn-data/tips.csv")
sns.violinplot(x="sex",y="total_bill",hue="smoker",data=df,orient='v')
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
df = pd.read_csv("seaborn-data/tips.csv")
sns.swarmplot(x="sex",y="total_bill",hue="smoker",data=df,orient='v')
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
df = pd.read_csv("seaborn-data/tips.csv")
sns.stripplot(x="sex",y="total_bill",hue="smoker",data=df,orient='v')
plt.show()

# %%
sns.swarmplot(x='sex',y='total_bill',data=df,hue='time',palette='rainbow')
sns.violinplot(x='sex',y='total_bill',data=df,hue='time',palette='rainbow',split=True)
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
x = [ 'india','pakshitan','australia']
y = [ 56,45,55]

sns.barplot(x,y)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='sex',data=df,hue='smoker',dodge=False,palette='coolwarm')
plt.show()

# %%
sns.countplot(x='size',data=df,hue='smoker',dodge=False,palette='coolwarm')
plt.show()

# %%
df  = pd.read_csv("seaborn-data/flights.csv")

# %%
df.shape
# Out:
# (144, 3)

# %%
df.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
data = df.pivot_table(index='year',columns='month',values='passengers')

# %%
data.columns
# Out:
# Index(['April', 'August', 'December', 'February', 'January', 'July', 'June',
#        'March', 'May', 'November', 'October', 'September'],
#       dtype='object', name='month')

# %%
data.head()
# Out:
# month  April  August  December  February  January  July  June  March  May  \
# year
# 1949     129     148       118       118      112   148   135    132  121
# 1950     135     170       140       126      115   170   149    141  125
# 1951     163     199       166       150      145   199   178    178  172
# 1952     181     242       194       180      171   230   218    193  183
# 1953     235     272       201       196      196   264   243    236  229
#
# month  November  October  September
# year
# 1949        104      119        136
# 1950        114      133        158
# 1951        146      162        184
# 1952        172      191        209
# 1953        180      211        237

# %%
df.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
df.groupby("month")["passengers"].count()
# Out:
# month
# April        12
# August       12
# December     12
# February     12
# January      12
# July         12
# June         12
# March        12
# May          12
# November     12
# October      12
# September    12
# Name: passengers, dtype: int64

# %%
data.head()
# Out:
# month  April  August  December  February  January  July  June  March  May  \
# year
# 1949     129     148       118       118      112   148   135    132  121
# 1950     135     170       140       126      115   170   149    141  125
# 1951     163     199       166       150      145   199   178    178  172
# 1952     181     242       194       180      171   230   218    193  183
# 1953     235     272       201       196      196   264   243    236  229
#
# month  November  October  September
# year
# 1949        104      119        136
# 1950        114      133        158
# 1951        146      162        184
# 1952        172      191        209
# 1953        180      211        237

# %%
sns.heatmap(data.corr(),cmap="coolwarm")
plt.show()

# %%
sns.heatmap(data,cmap="coolwarm")
plt.show()

# %%
data  = df.pivot_table(columns="year",index="month",values="passengers")
sns.clustermap(data,cmap="coolwarm")
plt.show()

# %%
dm = sns.load_dataset("diamonds")

# %%
dm.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.countplot(x='cut',data=dm,hue='color',dodge=False,palette='coolwarm')
plt.show()

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 92FD-5B19
#
#  Directory of C:\Users\hp\Desktop\Batches\SummerInternBatch2019\Batch10_30\data_science
#
# 15-06-2019  12:57    <DIR>          .
# 15-06-2019  12:57    <DIR>          ..
# 15-06-2019  11:12    <DIR>          .ipynb_checkpoints
# 13-06-2019  13:01             1,865 .live.py.un~
# 03-05-2019  20:22           150,486 1.Descriptive_Stats.ipynb
# 10-06-2019  12:47            28,710 1.Numpy_Introduction.ipynb
# 02-05-2019  09:56             3,570 1.SuperViseUnsuperVise.ipynb
# 12-06-2019  12:54           224,932 2.DataVisualization.ipynb
# 14-06-2019  12:03            79,557 3.Graphs.ipynb
# 13-06-2019  12:57           738,884 3.Visulation.ipynb
# 14-06-2019  12:57           173,285 4.Pandas.ipynb
# 15-06-2019  12:54           680,105 5.Seaborn.ipynb
# 23-05-2019  14:46             9,956 6.Normal_Distribution_Theory.ipynb
# 23-11-2017  01:33        15,442,270 deliveries.csv
# ...

# %%
df = pd.read_csv('matches.csv')

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.head()
# Out:
#    season       city        date                        team1  \
# 0    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2017       Pune  2017-04-06               Mumbai Indians
# 2    2017     Rajkot  2017-04-07                Gujarat Lions
# 3    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
sns.countplot("city",data=df)
plt.xticks(rotation=90,fontsize=10)
plt.show()

# %%
sns.countplot("player_of_match",data=df)
plt.xticks(rotation=90,fontsize=10)
plt.show()

# %%
df['player_of_match'].value_counts()[:15].plot(kind='bar')
