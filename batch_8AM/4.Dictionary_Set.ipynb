# %% [markdown]
# ### Dictionary

# %% [markdown]
# We have users information as
#
#     Name      Acc Num       Balance    Password
#
#     john      12345         50000      @1234@5
#     natsha    12356         45000      @pass@123
#     hari      12333         50000      @let'splay

# %%
bank_data = [ 'john',12345,50000,"@1234@5","natsha",12356,45000,"@pass@123",
            "hari",12333,50000,"@let'splay"]

# %%
bank_data = [
    
    ["john",12345,50000,"@1234@5"],
    ["natsha",12356,56000,"@pass@123"],
    ["hari",12333,50000,"@let'splay"],
]

# %%
bank_data[1][2] = bank_data[1][2] - 7500

# %%
bank_data
# Out:
# [['john', 12345, 50000, '@1234@5'],
#  ['natsha', 12356, 48500, '@pass@123'],
#  ['hari', 12333, 50000, "@let'splay"]]

# %%
# sam,343434,123456,'nopassword'

# %%
new_user = [ "sam",343434,123456,'nopassword']

# %%
bank_data.append(new_user)

# %%
bank_data
# Out:
# [['john', 12345, 50000, '@1234@5'],
#  ['natsha', 12356, 48500, '@pass@123'],
#  ['hari', 12333, 50000, "@let'splay"],
#  ['sam', 343434, 123456, 'nopassword']]

# %%
bank_data.pop(-2)
# Out:
# ['hari', 12333, 50000, "@let'splay"]

# %%
bank_data
# Out:
# [['john', 12345, 50000, '@1234@5'],
#  ['natsha', 12356, 48500, '@pass@123'],
#  ['sam', 343434, 123456, 'nopassword']]

# %%
t = (1,2,3,4,"hello")

# %%
t[::-1]
# Out:
# ('hello', 4, 3, 2, 1)

# %%
t[3] = "hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-b1f0aa6583ce> in <module>
# ----> 1 t[3] = "hello"
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(dir(tuple))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %% [markdown]
# ## Dictionary
#
# #### Dictionaries are Mutable
# #### Dictionaries are un-ordered map type object
# #### Dictionaries are collection of key-value pairs
# #### Dictionaries should be hashable (immutable)
# #### Values in Dictionary can be any type

# %%
hash("hello")
# Out:
# 4282648575613688385

# %%
hash("hello")
# Out:
# 4282648575613688385

# %%
s  = "hello"

# %%
hash(s)
# Out:
# 4282648575613688385

# %%
s = "hello world"

# %%
hash(s)
# Out:
# 8231482469892975187

# %%
hash(input("Enter strin"))
# Out:
# Enter strinhello world
# 8231482469892975187

# %%
l = [ 1,2,3,4,5]

# %%
hash(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-7a4e953a7f49> in <module>
# ----> 1 hash(l)
#
# TypeError: unhashable type: 'list'

# %%
t  = (1,2,3,4,5)
hash(t)
# Out:
# 8315274433719620810

# %%
data = { "key1":"value1","key2":"value2",}

# %%
data
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
data = { 'name':'sachin','name':'python','name':'grras'}

# %%
print(data)
# Out:
# {'name': 'grras'}

# %%
data['est_year'] = 2008

# %%
data
# Out:
# {'name': 'grras', 'est_year': 2008}

# %%
data[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-80a4aab09c73> in <module>
# ----> 1 data[0]
#
# KeyError: 0

# %%
data['name']
# Out:
# 'grras'

# %%
info = {
    'name':'rahul',
    'age' : 18,
    'country':'india',
    'father_name' : 'sanjay',
    'education' : { 'school' : 88,
                    'high_school' : 84,
                    'graduation' : "70% till 5th sem" 
                    },
    'skills' :  [ 'java','c','c++','html','javascript'],
    
}

# %%
info
# Out:
# {'name': 'rahul',
#  'age': 18,
#  'country': 'india',
#  'father_name': 'sanjay',
#  'education': {'school': 88,
#   'high_school': 84,
#   'graduation': '70% till 5th sem'},
#  'skills': ['java', 'c', 'c++', 'html', 'javascript']}

# %%
print(info)
# Out:
# {'name': 'rahul', 'age': 18, 'country': 'india', 'father_name': 'sanjay', 'education': {'school': 88, 'high_school': 84, 'graduation': '70% till 5th sem'}, 'skills': ['java', 'c', 'c++', 'html', 'javascript']}

# %%
from pprint import pprint # pretty printer 
pprint(info)
# Out:
# {'age': 18,
#  'country': 'india',
#  'education': {'graduation': '70% till 5th sem',
#                'high_school': 84,
#                'school': 88},
#  'father_name': 'sanjay',
#  'name': 'rahul',
#  'skills': ['java', 'c', 'c++', 'html', 'javascript']}

# %%
info['education']['high_school']
# Out:
# 84

# %%
info['skills'][:5]
# Out:
# ['java', 'c', 'c++', 'html', 'javascript']

# %%
d = { 'name':'python','version':3.7,['version',1]:1994,}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-cdb312fbbb46> in <module>
# ----> 1 d = { 'name':'python','version':3.7,['version',1]:1994,}
#
# TypeError: unhashable type: 'list'

# %%
d = { 'name':'python','version':3.7,('version',1):1994,
    ('version',2):2000,('version',3):2008}

# %%
d
# Out:
# {'name': 'python',
#  'version': 3.7,
#  ('version', 1): 1994,
#  ('version', 2): 2000,
#  ('version', 3): 2008}

# %%
d[('version',3)]
# Out:
# 2008

# %%
d = { 'one':'two','two':'three'}

# %%
d['one']
# Out:
# 'two'

# %%
d['two']
# Out:
# 'three'

# %%
d['one'] = 'first comes first'

# %%
print(d)
# Out:
# {'one': 'first comes first', 'two': 'three'}

# %%
d['one']
# Out:
# 'first comes first'

# %%
d['four']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-99f82dfe25e5> in <module>
# ----> 1 d['four']
#
# KeyError: 'four'

# %%
print(dir(dict))
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %% [markdown]
# ### Functions of dictionary
#
#     1. dict.clear() --> it will delete all key-value pairs
#     2. dict.copy() --> will return copy of original dict
#     3. dict.fromkeys(keys,default_value) --> create a new dictionary with keys having default_value
#     4. *dict.get(key,default) --> will return object on key if key exists else return default
#     5. *dict.items() --> will list of key-value pairs
#     6. dict.keys() --> will return list of keys
#     7. dict.pop(key) ---> will delete object map to key
#     8. dict.popitem() --> will delete arbitary object
#     9. *dict.setdefault(key,value) --> will return object if key exists else update a new key in dictionary have value value
#     10. *dict.update(collection of key-value pairs) --> will add and update key-value pairs in dictionary
#     11. dict.values() --> will return list of values

# %%
data
# Out:
# {'name': 'grras', 'est_year': 2008}

# %%
data.clear()

# %%
data
# Out:
# {}

# %%
data['name'] = 'grras'
data['est_year'] = 2008
data['name'] = 'Grras Solutions Pvt LTD.'

# %%
data
# Out:
# {'name': 'Grras Solutions Pvt LTD.', 'est_year': 2008}

# %%
data1 = data.copy()

# %%
data['HeadOffice'] = 'Jaipur'

# %%
pprint(data)
# Out:
# {'HeadOffice': 'Jaipur', 'est_year': 2008, 'name': 'Grras Solutions Pvt LTD.'}

# %%
pprint(data1)
# Out:
# {'est_year': 2008, 'name': 'Grras Solutions Pvt LTD.'}

# %%
data
# Out:
# {'name': 'Grras Solutions Pvt LTD.', 'est_year': 2008, 'HeadOffice': 'Jaipur'}

# %%
data.fromkeys(['key1','key2','key3'],"Default")
# Out:
# {'key1': 'Default', 'key2': 'Default', 'key3': 'Default'}

# %%
new_data = data.fromkeys(data.keys(),None)

# %%
data
# Out:
# {'name': 'Grras Solutions Pvt LTD.', 'est_year': 2008, 'HeadOffice': 'Jaipur'}

# %%
data.get('name')
# Out:
# 'Grras Solutions Pvt LTD.'

# %%
data.get('est_year')
# Out:
# 2008

# %%
data['name']
# Out:
# 'Grras Solutions Pvt LTD.'

# %%
data['something']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-adf8099db62a> in <module>
# ----> 1 data['something']
#
# KeyError: 'something'

# %%
key = input("Enter your query : ").strip().lower()
data.get(key,"no such key available")
# Out:
# Enter your query : md
# 'no such key available'

# %%
data.items()
# Out:
# dict_items([('name', 'Grras Solutions Pvt LTD.'), ('est_year', 2008), ('HeadOffice', 'Jaipur')])

# %%
mylist = list(data.items())

# %%
mylist
# Out:
# [('name', 'Grras Solutions Pvt LTD.'),
#  ('est_year', 2008),
#  ('HeadOffice', 'Jaipur')]

# %%
data.keys()
# Out:
# dict_keys(['name', 'est_year', 'HeadOffice'])

# %%
data.values()
# Out:
# dict_values(['Grras Solutions Pvt LTD.', 2008, 'Jaipur'])

# %%
data
# Out:
# {'name': 'Grras Solutions Pvt LTD.', 'est_year': 2008, 'HeadOffice': 'Jaipur'}

# %%
data.setdefault("name","Hello World")
# Out:
# 'Grras Solutions Pvt LTD.'

# %%
data.setdefault('type',"An IT company as well as Institute")
# Out:
# 'An IT company as well as Institute'

# %%
data
# Out:
# {'name': 'Grras Solutions Pvt LTD.',
#  'est_year': 2008,
#  'HeadOffice': 'Jaipur',
#  'type': 'An IT company as well as Institute'}

# %%
data
# Out:
# {'name': 'Grras Solutions Pvt LTD.',
#  'est_year': 2008,
#  'HeadOffice': 'Jaipur',
#  'type': 'An IT company as well as Institute'}

# %%
data.update(name="GRRAS")

# %%
data
# Out:
# {'name': 'GRRAS',
#  'est_year': 2008,
#  'HeadOffice': 'Jaipur',
#  'type': 'An IT company as well as Institute'}

# %%
data.update([ ('courses',["java","python","DS","ML","CLOUD","linus"]),
             ('type','Institute'),('md',["Gaurav","Rajat","Ravi","Akhlish"]), ])

# %%
data
# Out:
# {'name': 'GRRAS',
#  'est_year': 2008,
#  'HeadOffice': 'Jaipur',
#  'type': 'Institute',
#  'courses': ['java', 'python', 'DS', 'ML', 'CLOUD', 'linus'],
#  'md': ['Gaurav', 'Rajat', 'Ravi', 'Akhlish']}

# %%
data.pop('name')
# Out:
# 'GRRAS'

# %%
data
# Out:
# {'est_year': 2008,
#  'HeadOffice': 'Jaipur',
#  'type': 'Institute',
#  'courses': ['java', 'python', 'DS', 'ML', 'CLOUD', 'linus'],
#  'md': ['Gaurav', 'Rajat', 'Ravi', 'Akhlish']}

# %%
data.pop('sachin')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-b76b2cd46dee> in <module>
# ----> 1 data.pop('sachin')
#
# KeyError: 'sachin'

# %%
data.popitem()
# Out:
# ('md', ['Gaurav', 'Rajat', 'Ravi', 'Akhlish'])

# %%
d = dict(name='sachin',age=23,profession='cricketer',)

# %%
d
# Out:
# {'name': 'sachin', 'age': 23, 'profession': 'cricketer'}

# %%
d  = dict([('key1','value1'),('key2','value2'),('good','bad')])

# %%
d
# Out:
# {'key1': 'value1', 'key2': 'value2', 'good': 'bad'}

# %%
d
# Out:
# {'key1': 'value1', 'key2': 'value2', 'good': 'bad'}

# %%
data
# Out:
# {'est_year': 2008,
#  'HeadOffice': 'Jaipur',
#  'type': 'Institute',
#  'courses': ['java', 'python', 'DS', 'ML', 'CLOUD', 'linus']}

# %%
print("python")
#print(*"python",sep='\n')# 
print('p','y','t','h','o','n',sep='\n')
# Out:
# python
# p
# y
# t
# h
# o
# n

# %%
print([1,'hello','bye'])
print(*[1,'hello','bye'],sep='\n')
# Out:
# [1, 'hello', 'bye']
# 1
# hello
# bye

# %%
print(*data)
# Out:
# est_year HeadOffice type courses

# %%
data
# Out:
# {'est_year': 2008,
#  'HeadOffice': 'Jaipur',
#  'type': 'Institute',
#  'courses': ['java', 'python', 'DS', 'ML', 'CLOUD', 'linus']}

# %%
print(**data) # 
print(est_yer=2008,HeadOffice='Jaipur')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-24149e825656> in <module>
# ----> 1 print(**data) #
#       2 print(est_yer=2008,HeadOffice='Jaipur')
#
# TypeError: 'est_year' is an invalid keyword argument for print()

# %%
meri = { **d,**data}

# %%
meri
# Out:
# {'key1': 'value1',
#  'key2': 'value2',
#  'good': 'bad',
#  'est_year': 2008,
#  'HeadOffice': 'Jaipur',
#  'type': 'Institute',
#  'courses': ['java', 'python', 'DS', 'ML', 'CLOUD', 'linus']}

# %%
name = input("Enter your name : ")
age = int(input("your age please : "))
# Out:
# Enter your name : sachin
# your age please : 25

# %%
d = { 'name':name,
     'age':age}

# %%
d
# Out:
# {'name': 'sachin', 'age': 25}

# %%
d = { 
    'name': input("Enter your name : "),
    'skills' : eval(input("Enter your skill as list : ")),
    'color' : input("Enter color")

}
# Out:
# Enter your name : sachin
# Enter your skill as list : ['c','c++','java','python','bash',]
# Enter colorfair

# %%
d
# Out:
# {'name': 'sachin',
#  'skills': ['c', 'c++', 'java', 'python', 'bash'],
#  'color': 'fair'}

# %%
d = {}
for _ in range(5):
    key_value = [ (input("key : "),eval(input("value : ")))]
    d.update(key_value)
# Out:
# key : name
# value : sachin
# key : age
# value : 23
# key : country
# value : india
# key : skills
# value : ['c','c++','java','python']
# key : blood_group
# value : B+ive

# %%
d
# Out:
# {'name': 'sachin',
#  'age': '23',
#  'country': 'india',
#  'skills': "['c','c++','java','python']",
#  'blood_group': 'B+ive'}

# %%
bool(input("Enter something : "))
# Out:
# Enter something :
# False

# %%
d  = {}
while input("Press any key to continue : ") : 
    key_value = [ (input("key : "),eval(input("value : ")))]
    d.update(key_value)
# Out:
# Press any key to continue : k
# key : name
# value : 'sachin'
# Press any key to continue : k
# key : skills
# value : ['c','c++','java']
# Press any key to continue : k
# key : education
# value : {'school':88,'high_school':87,'b.tech':78}
# Press any key to continue :

# %%
d
# Out:
# {'name': 'sachin',
#  'skills': ['c', 'c++', 'java'],
#  'education': {'school': 88, 'high_school': 87, 'b.tech': 78}}
